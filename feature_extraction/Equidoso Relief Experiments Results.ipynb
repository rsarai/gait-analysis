# %% [markdown]
# # Experiments
# - The goal is to find the features that most represent the final evaluation state
# - Use T0, T3, T6, T9 and T12 to predict the Group (GC or GE)
#
# # Preprocessing
# - Remove patients with NaNs on T evaluations
#
# # Assessment
# - Feature selection improved the results of the basic classifiers.
# - However, the classifiers used are simple.
# - The build of a robust classifier is necessary to evaluate the feature selection algorithms
#
# # Experiment #1
# - Using only measurements T0 and T2 to predict the group (GC or GE)
# - Samples:  22
# - Columns:  159
# - Varying the number of features
# - Best result is found with 3 features:
#     - BIOF_T0
#     - CTSIB_Total_T0
#     - CTSIB_Total_T0
# - Assessment: The optimal number of features improved the results from the classifier, however there is a lot variability in the metrics

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 3 features
r_fs[1]['top_features']
# Out:
#            Features     Score
# 108         BIOF_T0  0.297521
# 112  CTSIB_Total_T0  0.264463
# 135   SF36_Pain_T12  0.206612

# %% [markdown]
# # Experiment #2
# - Using only measurements from T0 to predict the group (GC or GE)
# - Varying the number of features
# - Samples:  52
# - Columns:  82
# - Best result is found with 6 features:
#     - BIOF_T0
#     - CTSIB_Total_T0
#     - SwingSpeed_D_TS_T0
#     - SF36_PF_T0
#     - Gait_Assimetry_DTPV_T0
#     - BEOA_T0
# - Assessment: The optimal number of features improved the results from the classifier.

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 6 features
r_fs[4]['top_features']
# Out:
#                   Features     Score
# 56                 BIOF_T0  0.099112
# 58          CTSIB_Total_T0  0.081361
# 15      SwingSpeed_D_TS_T0  0.054231
# 64              SF36_PF_T0  0.042792
# 19  Gait_Assimetry_DTPV_T0  0.039463
# 52                 BEOA_T0  0.036982

# %% [markdown]
# # Experiment #3
# - Using all subjects that went to all measurements to predict Group
# - Varying the number of features
# - Samples:  17
# - Columns:  390
# - Best classifier result happens with 21 features
#     - SF36_Pain_T12
#     - StrideLength_D_DTPV_T9
#     - CTSIB_Total_T0
#     - GDS_T12
#     - SF36_VEF_T9
#     - BEDO_T3
#     - StrideLength_D_DTPF_T12
#     - SF36_GMH_T9
#     - EERE_T3
#     - SF36_Pain_T3
#     - StrideVelocity_D_DTPV_T9
#     - Gait_Speed_DTPV_T9
#     - MinToe_D_DTPV_T12
#     - MinToe_D_TS_T9
#     - SF36_RLEP_T6
#     - StrideLength_D_DTPV_T12
#     - StrideLength_D_TS_T12
#     - MinToe_D_DTPV_T0
#     - GDS_T3
#     - SF36_PF_T12
#     - MinToe_D_DTPV_T3
# - Assessment: This experiment had less samples. I don't trust the results. Especially because some results range from [0-1]

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 21 features
r_fs[19]['top_features']
# Out:
#                      Features     Score
# 342             SF36_Pain_T12  0.353758
# 97     StrideLength_D_DTPV_T9  0.308320
# 274            CTSIB_Total_T0  0.283497
# 303                   GDS_T12  0.266340
# 337               SF36_VEF_T9  0.264706
# 255                   BEDO_T3  0.264706
# 163   StrideLength_D_DTPF_T12  0.242599
# 335               SF36_GMH_T9  0.235294
# 225                   EERE_T3  0.228758
# 315              SF36_Pain_T3  0.223856
# 102  StrideVelocity_D_DTPV_T9  0.222272
# 72         Gait_Speed_DTPV_T9  0.222272
# 133         MinToe_D_DTPV_T12  0.222222
# 67             MinToe_D_TS_T9  0.222222
# 327              SF36_RLEP_T6  0.220588
# 98    StrideLength_D_DTPV_T12  0.220316
# 33      StrideLength_D_TS_T12  0.219708
# 129          MinToe_D_DTPV_T0  0.214052
# 300                    GDS_T3  0.213235
# 340               SF36_PF_T12  0.212418
# 130          MinToe_D_DTPV_T3  0.211601

# %% [markdown]
# # Using Data with Imputation

# %% [markdown]
# # Experiment #1
# - Using only measurements T0 and T2 to predict the group (GC or GE)
# - Samples:  60
# - Columns:  159
# - Varying the number of features
# - Best result is found with 3 features:
#     - BIOF_T0
#     - SwingSpeed_D_TS_T0
#     - CTSIB_Total_T0
# - Assessment: The optimal number of features improved the results from the classifier, however there is a lot variability in the metrics

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 3 features
r_fs[1]['top_features']
# Out:
#                Features     Score
# 108             BIOF_T0  0.073333
# 26   SwingSpeed_D_TS_T0  0.070275
# 112      CTSIB_Total_T0  0.070000

# %% [markdown]
# # Experiment #2
# - Using only measurements from T0 to predict the group (GC or GE)
# - Varying the number of features
# - Samples:  60
# - Columns:  82
# - Best result is found with 22 features:
# - Assessment: The optimal number of features improved the results from the classifier.

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 22 features
r_fs[20]['top_features']
# Out:
#                     Features     Score
# 56                   BIOF_T0  0.073333
# 15        SwingSpeed_D_TS_T0  0.070275
# 58            CTSIB_Total_T0  0.070000
# 64                SF36_PF_T0  0.060832
# 19    Gait_Assimetry_DTPV_T0  0.045205
# 6       Gait_Assimetry_TS_T0  0.039835
# 28      SwingSpeed_D_DTPV_T0  0.036693
# 1                      MASSA  0.036507
# 4           Gait_Speed_TS_T0  0.033714
# 14   PeakAngVelocity_D_TS_T0  0.031513
# 3                        IMC  0.026326
# 72              SF36_HCLY_T0  0.025556
# 5     Gait_Variability_TS_T0  0.025252
# 29          MinToe_D_DTPV_T0  0.023333
# 69              SF36_RLEP_T0  0.023333
# 71               SF36_GHP_T0  0.023194
# 23  StrideVelocity_D_DTPV_T0  0.022413
# 42          MinToe_D_DTPF_T0  0.021111
# 10    StrideVelocity_D_TS_T0  0.020507
# 49                   EERI_T0  0.018889
# 16            MinToe_D_TS_T0  0.018889
# 22    StrideLength_D_DTPV_T0  0.016915

# %% [markdown]
# # Experiment #3
# - Using all subjects that went to all measurements to predict Group
# - Varying the number of features
# - Samples:  60
# - Columns:  390
# - Best classifier result happens with 2 features
# - Assessment: results didn't improved much with the new data

# %%
assert len(results_with_feature_selection) == 28
assert len(regular_results)  == 1

r_fs = results_with_feature_selection
rr = regular_results

labels = list(range(2, 30))
accuracy_with_relief = [result['accuracy'] for result in r_fs]
accuracy_without_relief = [result['accuracy'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, accuracy_with_relief, accuracy_without_relief, "Accuracy")

precision_with_relief = [result['precision'] for result in r_fs]
precision_without_relief = [result['precision'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, precision_with_relief, precision_without_relief, "Precision")

recall_with_relief = [result['recall'] for result in r_fs]
recall_without_relief = [result['recall'] for result in rr]
box_plot_of_classifiers_with_and_without_relief(labels, recall_with_relief, recall_without_relief, "Recall")

# best classifier result happens with 2 features
r_fs[0]['top_features']
# Out:
#            Features     Score
# 66   MinToe_D_TS_T6  0.083333
# 347    SF36_HCLY_T9  0.074044
